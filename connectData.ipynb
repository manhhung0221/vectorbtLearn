# %%
import pandas as pd
import vectorbt as vbt
from sqlalchemy.engine import Engine
from sqlalchemy import text
from manage_engine import engine_stockDB

class Connect(vbt.Data):
    """
    DataSource cho vectorbt lấy OHLCV từ bảng eod.eod_stock_v2.

    Yêu cầu:
    - Truyền vào `engine` (SQLAlchemy Engine)
    - Trả về DataFrame index = DateTime, columns = [Open, High, Low, Close, Volume]
    """

    @classmethod
    def download_symbol(
        cls,
        symbol: str,
        *,
        engine: Engine,
        start: str | None = None,
        end: str | None = None,
        **kwargs,
    ) -> pd.DataFrame:
        """
        Hàm này được vectorbt gọi ngầm khi dùng Connect.fetch(...)

        Parameters
        ----------
        symbol : mã cổ phiếu, ví dụ 'HPG'
        engine : SQLAlchemy Engine kết nối tới Postgres
        start, end : chuỗi ngày 'YYYY-MM-DD' hoặc None
        """

        if engine is None:
            raise ValueError("Bạn phải truyền `engine=` (SQLAlchemy Engine) vào Connect.fetch(...)")

        # Base query
        sql = """
        SELECT
            "DateTime" AS dt,
            "Open"     AS "open",
            "High"     AS "high",
            "Low"      AS "low",
            "Close"    AS "close",
            "Volume"   AS "volume"
        FROM eod.eod_stock_v2
        WHERE ticker = :symbol
        """

        params: dict = {"symbol": symbol}

        # Thêm điều kiện ngày nếu có
        if start is not None:
            sql += ' AND "DateTime"::date >= :start'
            params["start"] = start
        if end is not None:
            sql += ' AND "DateTime"::date <= :end'
            params["end"] = end

        sql += ' ORDER BY "DateTime"'

        df = pd.read_sql_query(text(sql), engine, params=params)

        if df.empty:
            # Cho vectorbt biết là symbol này không có dữ liệu
            return df

        # Set index đúng kiểu time series
        df.set_index("dt", inplace=True)
        df.index.name = None  # cho đẹp, không bắt buộc

        # Đảm bảo đúng format OHLCV mà vectorbt thích
        # Cột đã rename sẵn ở query, nên chỉ cần return df
        return df

# %%
data = Connect.download(
    ['HPG'],
    engine=engine_stockDB,
    start="2022-01-01",
    end="2024-12-31",
)

df_ohlcv = data.get()

# %%
import vectorbtpro as vbt

# %%
client = vbt.TVData.resolve_client(username="hoangmanhhungf", password="Manhhung022193@")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client = vbt.TVData.resolve_client(username="hoangmanhhungf", password="Manhhung022193@")
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\custom\tv.py:1022, in TVData.resolve_client(cls, client, **client_config)
#    1020 client_config = cls.resolve_custom_setting(client_config, "client_config", merge=True)
#    1021 if client is None:
# -> 1022     client = TVClient(**client_config)
#    1023 elif has_client_config:
#    1024     raise ValueError("Cannot apply client_config to already initialized client")
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\custom\tv.py:203, in TVClient.__init__(self, username, password, auth_token, **kwargs)
#     194 Configured.__init__(
#     195     self,
#     196     username=username,
#    (...)
#     199     **kwargs,
#     200 )
#     202 if auth_token is None:
# --> 203     auth_token = self.auth(username, password)
#     204 elif username is not None or password is not None:
#     205     warn("Username, password, and auth_token were provided. Using auth_token only.")
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\custom\tv.py:270, in TVClient.auth(cls, username, password)
#     268     json = response.json()
#     269     if "user" not in json or "auth_token" not in json["user"]:
# --> 270         raise ValueError(json)
#     271     return json["user"]["auth_token"]
#     272 if username is not None or password is not None:
#
# ValueError: {'error': 'Please confirm that you are not a robot by clicking the captcha box.', 'code': 'recaptcha_required'}

# %%
data = vbt.YFData.pull("AAPL")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = vbt.YFData.pull("AAPL")
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\base.py:4248, in Data.pull(cls, keys, keys_are_features, features, symbols, classes, level_name, tz_localize, tz_convert, missing_index, missing_columns, wrapper_kwargs, skip_on_error, silence_warnings, execute_kwargs, return_raw, **kwargs)
#    4245     fetch_kwargs[k] = key_fetch_kwargs
#    4247 key_index = cls.get_key_index(keys=keys, level_name=level_name, feature_oriented=keys_are_features)
# -> 4248 outputs = execute(tasks, size=len(keys), keys=key_index, **execute_kwargs)
#    4249 if return_raw:
#    4250     return outputs
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\utils\execution.py:3256, in execute(tasks, size, keys, executor, replace_executor, merge_to_engine_config, **kwargs)
#    3254     if replace_executor and len(kwargs) > 0:
#    3255         executor = executor.replace(**kwargs)
# -> 3256 return executor.run(tasks, size=size, keys=keys)
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\utils\execution.py:2706, in Executor.run(self, tasks, size, keys)
#    2704 if "n_chunks" not in template_context:
#    2705     template_context["n_chunks"] = 1
# -> 2706 results = self.call_execute(engine, tasks, size=size, keys=keys)
#    2707 results = self.call_post_execute_func(
#    2708     results,
#    2709     cache_chunks=cache_chunks,
#    (...)
#    2716     template_context=template_context,
#    2717 )
#    2718 return self.merge_results(
#    2719     results,
#    2720     keys=keys,
#    (...)
#    2725     template_context=template_context,
#    2726 )
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\utils\execution.py:2364, in Executor.call_execute(cls, engine, tasks, size, keys)
#    2352 """Call execution on the provided tasks using `ExecutionEngine.execute`.
#    2353
#    2354 Args:
#    (...)
#    2361     ExecResults: Results obtained from executing the tasks.
#    2362 """
#    2363 if isinstance(engine, ExecutionEngine):
# -> 2364     return engine.execute(tasks, size=size, keys=keys)
#    2365 func_arg_names = get_func_arg_names(engine)
#    2366 execute_kwargs = {}
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\utils\execution.py:365, in SerialEngine.execute(self, tasks, size, keys)
#     362         pbar.set_description(dict(zip(keys.names, [keys[0]])))
#     364 for i, (func, args, kwargs) in enumerate(tasks):
# --> 365     results.append(func(*args, **kwargs))
#     366     if isinstance(self.clear_cache, bool):
#     367         if self.clear_cache:
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\base.py:3987, in Data.try_fetch_symbol(cls, symbol, skip_on_error, silence_warnings, fetch_kwargs)
#    3985 except Exception as e:
#    3986     if not skip_on_error:
# -> 3987         raise e
#    3988     if not silence_warnings:
#    3989         warn(traceback.format_exc())
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\base.py:3980, in Data.try_fetch_symbol(cls, symbol, skip_on_error, silence_warnings, fetch_kwargs)
#    3978     fetch_kwargs = {}
#    3979 try:
# -> 3980     out = cls.fetch_symbol(symbol, **fetch_kwargs)
#    3981     if out is None:
#    3982         if not silence_warnings:
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\data\custom\yf.py:122, in YFData.fetch_symbol(cls, symbol, period, start, end, timeframe, tz, ticker_kwargs, **history_kwargs)
#      93 """Override `vectorbtpro.data.base.Data.fetch_symbol` to fetch a symbol from Yahoo Finance.
#      94
#      95 Args:
#    (...)
#     118     (e.g., volume in the example). It is primarily intended for demonstration purposes.
#     119 """
#     120 from vectorbtpro.utils.module_ import assert_can_import
# --> 122 assert_can_import("yfinance")
#     123 import yfinance as yf
#     125 period = cls.resolve_custom_setting(period, "period")
#
# File d:\stockvip\vectorbt\venv\Lib\site-packages\vectorbtpro\utils\module_.py:293, in assert_can_import(pkg_name)
#     291 link = metadata["link"]
#     292 if not check_installed(pkg_name):
# --> 293     raise ImportError(f"Please install {dist_name}{version_str}. See {link}.")
#     294 if version != "":
#     295     actual_version_parts = get_version(dist_name).split(".")
#
# ImportError: Please install yfinance>=0.2.56. See https://pypi.org/project/yfinance/.
